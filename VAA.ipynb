# %% [markdown]
# # Notebook Contents
#
# - [Imports](#Imports)
# - [Dataset](#Data)

# %% [markdown]
# # Imports

# %%
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data

# %%
data = pd.read_csv('./data/mlb-pitches.csv')
data.drop(columns = ['Unnamed: 0'], inplace = True)

data.dropna(subset = ['release_speed', 'release_pos_z', 'release_extension', 
                      'sz_top', 'pfx_-x', 'pfx_x', 'pfx_z', 'bauer_units'], inplace = True)
font_title = {
    'size': 12,
    'weight': 'bold',
    'verticalalignment': 'center_baseline',
    'horizontalalignment': 'center'
}

pd.set_option('max_columns', None)
print(data.shape)
data.head(3)
# Out:
# (705445, 76)
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2021-10-03           92.3           1.40           6.80
# 1         SL  2021-10-03           80.6           1.60           6.64
# 2         CU  2021-10-03           75.5           1.46           6.88
#
#    player_name  batter  pitcher events    description  zone  \
# 0  Smith, Will  596019   519293    out  hit_into_play   1.0
# 1  Smith, Will  596019   519293    NaN           foul   4.0
# 2  Smith, Will  596019   519293    NaN           foul   5.0
#
#                                                  des game_type stand p_throws  \
# 0  Francisco Lindor grounds out, third baseman Eh...         R     R        L
# 1  Francisco Lindor grounds out, third baseman Eh...         R     R        L
# 2  Francisco Lindor grounds out, third baseman Eh...         R     R        L
#
#   home_team away_team type  hit_location      bb_type  balls  strikes  \
# ...

# %%
features = ['release_speed', 'release_pos_z', 'release_extension', 'sz_top', 'pfx_x']
X = data[features]
y = data['bauer_units']

ss = StandardScaler()
X_scaled = ss.fit_transform(X)

lr = LinearRegression()
lr.fit(X_scaled, y)
pred = lr.predict(X_scaled)

print('Coefficients:', lr.coef_)
print('Intercept:', lr.intercept_)
print('MSE:', metrics.mean_squared_error(y, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y, pred)))
print('R2:', metrics.r2_score(y, pred))
# Out:
# Coefficients: [-1.63260015 -0.01727115 -0.26679266 -0.05736334  0.78321974]
# Intercept: 25.276317207115635
# MSE: 15.238176698105551
# RMSE: 3.9036107257391266
# R2: 0.21655485876246006

# %%
data['vaa'] = (25.2763 - (1.6326 * data['release_speed']) - (0.0173 * data['release_pos_z']) - 
              (0.2668 * data['release_extension']) - (0.0574 * data['sz_top']) + (0.7832 * data['pfx_x']))

# %%
data.vaa.min(), data.vaa.max()
# Out:
# (-159.96715, -16.051893)
