# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Clean data for modeling

pitch = pd.read_csv('../data/mlb-pitches.csv', index_col = [0])
pitch = pitch[['player_name', 'p_throws', 'pitch_type','release_speed', 'release_spin_rate', 'spin_axis', 
               'pfx_-x', 'pfx_z', 'bauer_units', 'effective_speed', 'release_pos_x', 'release_pos_z', 
               'release_extension', 'release_pos_y', 'plate_-x', 'plate_x', 'plate_z', 'type', 'balls','strikes', 
               'pitch_count', 'stand', 'bb_type', 'description', 'events', 'hit_distance_sc', 'launch_speed',
               'launch_angle', 'launch_speed_angle', 'estimated_ba_using_speedangle', 
               'estimated_woba_using_speedangle', 'woba_value', 'woba_denom', 'babip_value', 'iso_value', 
               'at_bat_number', 'pitch_number', 'inning', 'inning_topbot', 'home_score', 'away_score', 
               'post_home_score', 'post_away_score', 'on_1b', 'on_2b', 'on_3b', 'outs_when_up', 
               'delta_run_exp']].copy()

#pitch = (pitch[pitch['events'] != 'wild_pitch', 'passed_ball', 'stolen_base_2b'])

#Rename some columns
col_dict = {
    'release_speed': 'velo',
    'release_spin_rate': 'spin_rate',
    'launch_speed': 'exit_velo',
    'estimated_ba_using_speedangle': 'xba',
    'estimated_woba_using_speedangle': 'xwobacon'
}
pitch.rename(columns = col_dict, inplace = True)
pitch.to_csv('../data/model-data.csv')

# %%
# Run Expectany Table

# 2010-2015 Run Expectancy
matrix = [[0, 0, 0, 0, 0.481], [1, 0, 0, 0, 0.859], [0, 1, 0, 0, 1.100], [1, 1, 0, 0, 1.437], 
          [0, 0, 1, 0, 1.350], [1, 0, 1, 0, 1.784], [0, 1, 1, 0, 1.964], [1, 1, 1, 0, 2.292], 
          [0, 0, 0, 1, 0.254], [1, 0, 0, 1, 0.509], [0, 1, 0, 1, 0.664], [1, 1, 0, 1, 0.884], 
          [0, 0, 1, 1, 0.950], [1, 0, 1, 1, 1.130], [0, 1, 1, 1, 1.376], [1, 1, 1, 1, 1.541],
          [0, 0, 0, 2, 0.098], [1, 0, 0, 2, 0.224], [0, 1, 0, 2, 0.319], [1, 1, 0, 2, 0.429], 
          [0, 0, 1, 2, 0.353], [1, 0, 1, 2, 0.478], [0, 1, 1, 2, 0.580], [1, 1, 1, 2, 0.752]]

# 2019 Run Expectancy
#matrix = [[0, 0, 0, 0, 0.544], [1, 0, 0, 0, 0.935], [0, 1, 0, 0, 1.147], [1, 1, 0, 0, 1.537], 
#          [0, 0, 1, 0, 1.369], [1, 0, 1, 0, 1.759], [0, 1, 1, 0, 1.971], [1, 1, 1, 0, 2.362], 
#          [0, 0, 0, 1, 0.298], [1, 0, 0, 1, 0.564], [0, 1, 0, 1, 0.713], [1, 1, 0, 1, 0.979], 
#          [0, 0, 1, 1, 0.953], [1, 0, 1, 1, 1.219], [0, 1, 1, 1, 1.368], [1, 1, 1, 1, 1.634],
#          [0, 0, 0, 2, 0.115], [1, 0, 0, 2, 0.242], [0, 1, 0, 2, 0.339], [1, 1, 0, 2, 0.467], 
#          [0, 0, 1, 2, 0.391], [1, 0, 1, 2, 0.518], [0, 1, 1, 2, 0.615], [1, 1, 1, 2, 0.743]]

re = pd.DataFrame(matrix, columns = ['on_1b', 'on_2b', 'on_3b', 'outs_when_up', 're'])
re.to_csv('../data/run_expectancy_table.csv')

# %%
# wOBA by Count

woba_value = [['0-0', 0.310, 0.000, 1, 0, -0.037], ['0-0', 0.310, 0.000, 0, 1, 0.032], 
              ['0-1', 0.262, -0.037, 1, 0, -0.051], ['0-1', 0.262, -0.037, 0, 1, 0.024],
              ['0-2', 0.196, -0.087, 1, 0, -0.150], ['0-2', 0.196, -0.087, 0, 1, 0.021],
              ['1-0', 0.355, 0.035, 1, 0, -0.035], ['1-0', 0.355, 0.035, 0, 1, 0.088],
              ['1-1', 0.293, -0.013, 1, 0, -0.054], ['1-1', 0.293, -0.013, 0, 1, 0.048],
              ['1-2', 0.223, -0.067, 1, 0, -0.171], ['1-2', 0.223, -0.067, 0, 1, 0.038],
              ['2-0', 0.436, 0.097, 1, 0, -0.062], ['2-0', 0.436, 0.097, 0, 1, 0.143],
              ['2-1', 0.352, 0.032, 1, 0, -0.069], ['2-1', 0.352, 0.032, 0, 1, 0.064],
              ['2-2', 0.273, -0.028, 1, 0, -0.209], ['2-2', 0.273, -0.028, 0, 1, 0.085],
              ['3-0', 0.622, 0.239, 1, 0, -0.177], ['3-0', 0.622, 0.239, 0, 1, 0.051],
              ['3-1', 0.470, 0.123, 1, 0, -0.066], ['3-1', 0.470, 0.123, 0, 1, 0.168],
              ['3-2', 0.384, 0.057, 1, 0, -0.294], ['3-2', 0.384, 0.057, 0, 1, 0.234]]

woba_value = pd.DataFrame(woba_value, columns = ['pitch_count', 'count_woba_value', 'wraa',
                                                 'is_strike', 'is_ball', 'value_change'])
woba_value.to_csv('../data/count_woba_value.csv')

#count_woba = pd.read_csv('../data/count_woba_value.csv', index_col = [0])
#data = pd.merge(data, woba_value, how = 'left', on = ['pitch_count'])

#data['count_woba_diff'] = round(-data['count_woba_value'].diff(1), 3)
#data['count_woba_after'] = data['count_woba_value'] + data['count_woba_diff']
#data['count_woba_diff'].fillna(0, inplace = True)
#data['count_woba_after'].fillna(0, inplace = True)
##data['events'].fillna('na', inplace = True)
##data['count_woba_after'] = [0 if x != 'na' else y for (x, y) in zip(data['events'], data['count_woba_after'])]
#data['count_woba_diff'] = data['count_woba_after'] - data['count_woba_value']
#data['xRV'] = round((data['count_woba_diff']) / 1.15, 3)

# %%
# Add RV to model-data.csv

data = pd.read_csv('../data/model-data.csv', index_col = [0])
data.dropna(subset = ['pitch_type', 'velo', 'spin_rate', 'pfx_-x', 
                      'release_extension', 'delta_run_exp'], inplace = True)

#data = data[data['events'] != 'wild_pitch', 'passed_ball', 'stolen_base_2b']

data = data[data['events'] != 'wild_pitch']
data = data[data['events'] != 'passed_ball']
data = data[data['events'] != 'stolen_base_2b']

data['events'].replace(['sac_bunt', 'double_play', 'caught_stealing_2b', 'strikeout_double_play',
                        'other_out', 'sac_fly_double_play', 'pickoff_2b', 'pickoff_3b', 'triple_play'
                        'caught_stealing_home', 'pickoff_caught_stealing_2b', 'pickoff_3b', 
                        'sac_bunt_double_play', 'pickoff_caught_stealing_3b', 'pickoff_1b', 
                        'caught_stealing_3b', 'triple_play', 'caught_stealing_home', 
                        'strikeout'], 'field_out', inplace = True)
data['events'].replace(['catcher_interf'], 'field_error', inplace = True)

data['description'].replace(['called_strike', 'swinging_strike', 'swinging_strike_blocked', 'missed_bunt',
                             'foul'], 'strike', inplace = True)
data['description'].replace(['passed_ball', 'wild_pitch'], 'ball', inplace = True)

data['is_strike'] = [1 if x != 'B' else 0 for x in data['type']]
#data['is_strike'] = 
data['is_ball'] = [1 if x == 'B' else 0 for x in data['type']]

data['inning_topbot'] = data.inning_topbot.map({'Top': 0, 'Bot': 1})
data['on_1b'] = [1 if x > 1 else 0 for x in data['on_1b']]
data['on_2b'] = [1 if x > 1 else 0 for x in data['on_2b']]
data['on_3b'] = [1 if x > 1 else 0 for x in data['on_3b']]

data['final_pitch_ab'] = [1 if x == x else 0 for x in data['events']]
data['out_to_end_inning'] = [1 if x == 'field_out' and y == 2 else 0 for (x, y) 
                             in zip(data['events'], data['outs_when_up'])]
data['home_runs'] = data['post_home_score'] - data['home_score']
data['away_runs'] = data['post_away_score'] - data['away_score']
data['runs'] = data['home_runs'] + data['away_runs']

#re = pd.read_csv('../data/run_expectancy_table.csv', index_col = [0])
data = pd.merge(data, re, how = 'left', on = ['on_1b', 'on_2b', 'on_3b', 'outs_when_up'])

data['re_change'] = round(-data['re'].diff(1), 3)
data['re_change'].fillna(-0.098, inplace = True)
data['re_end_state'] = data['re'] + data['re_change']
data['re_end_state'] = [0 if x == 1 else y for (x, y) in zip(data['out_to_end_inning'], data['re_end_state'])]
data['re_change'] = [-y if x == 1 else z for (x, y, z) in zip(data['out_to_end_inning'], 
                                                              data['re'], data['re_change'])]
data['re_change'].replace([-0.000], 0, inplace = True)
data['re24'] = data['re_change'] + data['runs']
#mlb_lw = data.groupby(['events', 'on_1b', 'on_2b', 'on_3b', 'outs_when_up'], as_index = False)['re24'].mean()
mlb_lw = data.groupby(['events'], as_index = False)['re24'].mean()
lw = pd.DataFrame(mlb_lw)
lw['re24'] = round(lw['re24'], 3)
lw.rename(columns = {'re24': 'lin_weight_above_avg'}, inplace = True)
# for lin weights based on base out state 
#data = pd.merge(data, lw, how = 'left', on = ['events', 'on_1b', 'on_2b', 'on_3b', 'outs_when_up'])
data = pd.merge(data, lw, how = 'left', on = ['events'])
data['lin_weight_above_outs'] = data['lin_weight_above_avg'] + 0.250
data['woba_scale'] = 1.209
data['final_lin_weights'] = round(data['lin_weight_above_outs'] * data['woba_scale'], 3)
#data['lin_weight'].fillna(0, inplace = True)

count_woba = pd.read_csv('../data/count_woba_value.csv', index_col = [0])
data = pd.merge(data, woba_value, how = 'left', on = ['pitch_count', 'is_strike', 'is_ball'])
data['value_after'] = data['wraa'] + data['value_change'] 

data.to_csv('../data/model-pitches-rv.csv')

pd.set_option('max_columns', None)
print(data.shape)
data.head(10)
# Out:
# (705396, 67)
#         player_name p_throws pitch_type  velo  spin_rate  spin_axis  pfx_-x  \
# 0       Smith, Will        L         FF  92.3     2330.0      148.0   -8.28
# 1       Smith, Will        L         SL  80.6     2254.0      315.0    9.24
# 2       Smith, Will        L         CU  75.5     1940.0      328.0    7.80
# 3       Smith, Will        L         CU  75.0     2017.0      330.0    8.28
# 4       Smith, Will        L         FF  91.2     2281.0      143.0   -7.56
# 5       Smith, Will        L         FF  92.5     2319.0      145.0   -6.48
# 6       Smith, Will        L         SL  80.3     2328.0      304.0    3.96
# 7       Smith, Will        L         SL  79.5     2368.0      306.0    6.00
# 8       Smith, Will        L         FF  91.8     2299.0      146.0   -8.88
# 9  Gsellman, Robert        R         SI  94.3     1982.0      221.0   16.20
#
#    pfx_z  bauer_units  effective_speed  release_pos_x  release_pos_z  \
# 0  16.56    25.243770             92.8           1.40           6.80
# 1   5.76    27.965261             81.2           1.60           6.64
# 2  -6.12    25.695364             75.2           1.46           6.88
# 3  -8.28    26.893333             74.5           1.53           6.83
# 4  15.36    25.010965             90.9           1.49           6.66
# 5  17.40    25.070270             92.0           1.35           6.74
# 6   2.16    28.991283             80.8           1.81           6.55
# 7   4.56    29.786164             79.4           1.72           6.56
# 8  17.64    25.043573             91.8           1.39           6.75
# 9  10.56    21.018028             94.4          -1.20           6.05
#
#    release_extension  release_pos_y  plate_-x  plate_x  plate_z type  balls  \
# 0                6.5          54.03      0.69    -0.69     2.83    X      1
# 1                6.4          54.15      0.71    -0.71     2.62    S      1
# 2                6.2          54.34      0.04    -0.04     2.46    S      1
# 3                5.9          54.61     -2.10     2.10     3.89    B      0
# 4                6.3          54.15      0.31    -0.31     2.80    X      1
# 5                6.3          54.19      1.04    -1.04     3.58    B      0
# 6                6.2          54.30      0.69    -0.69     0.83    S      0
# 7                6.1          54.44     -0.12     0.12     1.99    S      0
# 8                6.5          54.04      0.72    -0.72     2.77    S      0
# 9                6.5          53.98      0.26    -0.26     1.78    X      0
#
#    strikes pitch_count stand      bb_type    description     events  \
# 0        2         1-2     R  ground_ball  hit_into_play  field_out
# 1        1         1-1     R          NaN         strike        NaN
# 2        0         1-0     R          NaN         strike        NaN
# 3        0         0-0     R          NaN           ball        NaN
# 4        0         1-0     L  ground_ball  hit_into_play  field_out
# 5        0         0-0     L          NaN           ball        NaN
# 6        2         0-2     L          NaN         strike  field_out
# 7        1         0-1     L          NaN         strike        NaN
# 8        0         0-0     L          NaN         strike        NaN
# 9        2         0-2     R        popup  hit_into_play  field_out
#
#    hit_distance_sc  exit_velo  launch_angle  launch_speed_angle    xba  \
# 0             13.0       95.2         -13.0                 2.0  0.174
# 1            108.0       75.3          75.0                 NaN    NaN
# 2            157.0       83.5          65.0                 NaN    NaN
# 3              NaN        NaN           NaN                 NaN    NaN
# 4              9.0       93.3         -18.0                 2.0  0.100
# 5              NaN        NaN           NaN                 NaN    NaN
# 6              NaN        NaN           NaN                 NaN    NaN
# 7              NaN        NaN           NaN                 NaN    NaN
# 8              NaN        NaN           NaN                 NaN    NaN
# 9            140.0       75.3          65.0                 3.0  0.000
#
#    xwobacon  woba_value  woba_denom  babip_value  iso_value  at_bat_number  \
# 0     0.158         0.0         1.0          0.0        0.0             61
# 1       NaN         NaN         NaN          NaN        NaN             61
# 2       NaN         NaN         NaN          NaN        NaN             61
# 3       NaN         NaN         NaN          NaN        NaN             61
# 4     0.090         0.0         1.0          0.0        0.0             60
# 5       NaN         NaN         NaN          NaN        NaN             60
# 6       NaN         0.0         1.0          0.0        0.0             59
# 7       NaN         NaN         NaN          NaN        NaN             59
# 8       NaN         NaN         NaN          NaN        NaN             59
# 9     0.000         0.0         1.0          0.0        0.0             58
#
#    pitch_number  inning  inning_topbot  home_score  away_score  \
# 0             4       9              0           5           0
# 1             3       9              0           5           0
# 2             2       9              0           5           0
# 3             1       9              0           5           0
# 4             2       9              0           5           0
# 5             1       9              0           5           0
# 6             3       9              0           5           0
# 7             2       9              0           5           0
# 8             1       9              0           5           0
# 9             3       8              1           5           0
#
#    post_home_score  post_away_score  on_1b  on_2b  on_3b  outs_when_up  \
# 0                5                0      0      0      0             2
# 1                5                0      0      0      0             2
# 2                5                0      0      0      0             2
# 3                5                0      0      0      0             2
# 4                5                0      0      0      0             1
# 5                5                0      0      0      0             1
# 6                5                0      0      0      0             0
# 7                5                0      0      0      0             0
# 8                5                0      0      0      0             0
# 9                5                0      0      0      0             2
#
#    delta_run_exp  is_strike  is_ball  final_pitch_ab  out_to_end_inning  \
# 0         -0.073          1        0               1                  1
# 1         -0.027          1        0               0                  0
# 2         -0.020          1        0               0                  0
# 3          0.016          0        1               0                  0
# 4         -0.189          1        0               1                  0
# 5          0.026          0        1               0                  0
# 6         -0.152          1        0               1                  0
# 7         -0.052          1        0               0                  0
# 8         -0.038          1        0               0                  0
# 9         -0.061          1        0               1                  1
#
#    home_runs  away_runs  runs     re  re_change  re_end_state   re24  \
# 0          0          0     0  0.098     -0.098         0.000 -0.098
# 1          0          0     0  0.098      0.000         0.098  0.000
# 2          0          0     0  0.098      0.000         0.098  0.000
# 3          0          0     0  0.098      0.000         0.098  0.000
# 4          0          0     0  0.254     -0.156         0.098 -0.156
# 5          0          0     0  0.254      0.000         0.254  0.000
# 6          0          0     0  0.481     -0.227         0.254 -0.227
# 7          0          0     0  0.481      0.000         0.481  0.000
# 8          0          0     0  0.481      0.000         0.481  0.000
# 9          0          0     0  0.098     -0.098         0.000 -0.098
#
#    lin_weight_above_avg  lin_weight_above_outs  woba_scale  final_lin_weights  \
# 0                 -0.25                    0.0       1.209                0.0
# 1                   NaN                    NaN       1.209                NaN
# 2                   NaN                    NaN       1.209                NaN
# 3                   NaN                    NaN       1.209                NaN
# 4                 -0.25                    0.0       1.209                0.0
# 5                   NaN                    NaN       1.209                NaN
# 6                 -0.25                    0.0       1.209                0.0
# 7                   NaN                    NaN       1.209                NaN
# 8                   NaN                    NaN       1.209                NaN
# 9                 -0.25                    0.0       1.209                0.0
#
#    count_woba_value   wraa  value_change  value_after
# 0             0.223 -0.067        -0.171       -0.238
# 1             0.293 -0.013        -0.054       -0.067
# 2             0.355  0.035        -0.035        0.000
# 3             0.310  0.000         0.032        0.032
# 4             0.355  0.035        -0.035        0.000
# 5             0.310  0.000         0.032        0.032
# 6             0.196 -0.087        -0.150       -0.237
# 7             0.262 -0.037        -0.051       -0.088
# 8             0.310  0.000        -0.037       -0.037
# 9             0.196 -0.087        -0.150       -0.237

# %%
#data.groupby(['events', 'on_1b', 'on_2b', 'on_3b', 'outs_when_up'], as_index = False)['re24'].mean()
data.groupby(['events'], as_index = False)['re24', 'lin_weight_above_avg', 
                                           'lin_weight_above_outs', 'final_lin_weights'].mean()
# Out:
#          events      re24  lin_weight_above_avg  lin_weight_above_outs  \
# 0        double  0.765841                 0.766                  1.016
# 1   field_error  0.427661                 0.428                  0.678
# 2     field_out -0.249793                -0.250                  0.000
# 3  hit_by_pitch  0.340325                 0.340                  0.590
# 4      home_run  1.394975                 1.395                  1.645
# 5        single  0.457643                 0.458                  0.708
# 6        triple  1.052801                 1.053                  1.303
# 7          walk  0.313550                 0.314                  0.564
#
#    final_lin_weights
# 0              1.228
# 1              0.820
# 2              0.000
# 3              0.713
# 4              1.989
# 5              0.856
# 6              1.575
# 7              0.682

# %%
data2 = data.copy()
data2.dropna(subset = ['events'], inplace = True)

#data2.to_csv('../data/model-plate-app-rv.csv')
print(data2.shape)
data2.head(10)
# Out:
# (180159, 67)
#          player_name p_throws pitch_type  velo  spin_rate  spin_axis  pfx_-x  \
# 0        Smith, Will        L         FF  92.3     2330.0      148.0   -8.28
# 4        Smith, Will        L         FF  91.2     2281.0      143.0   -7.56
# 6        Smith, Will        L         SL  80.3     2328.0      304.0    3.96
# 9   Gsellman, Robert        R         SI  94.3     1982.0      221.0   16.20
# 12  Gsellman, Robert        R         SL  90.8     2052.0      215.0    0.36
# 18  Gsellman, Robert        R         SL  90.5     2133.0      216.0   -0.12
# 22     Martin, Chris        R         CH  87.9     1160.0      234.0    7.68
# 27     Martin, Chris        R         FF  94.9     2224.0      216.0    9.00
# 28     Martin, Chris        R         FC  91.1     2156.0      177.0   -3.00
# 30    Hembree, Heath        R         FF  93.5     2419.0      219.0   12.12
#
#     pfx_z  bauer_units  effective_speed  release_pos_x  release_pos_z  \
# 0   16.56    25.243770             92.8           1.40           6.80
# 4   15.36    25.010965             90.9           1.49           6.66
# 6    2.16    28.991283             80.8           1.81           6.55
# 9   10.56    21.018028             94.4          -1.20           6.05
# 12   5.04    22.599119             90.9          -1.48           5.95
# 18   7.44    23.569061             91.1          -1.51           5.93
# 22   1.80    13.196815             88.8          -2.98           6.23
# 27  14.16    23.435195             95.5          -2.71           6.38
# 28   5.28    23.666301             92.1          -2.85           6.39
# 30  17.28    25.871658             93.9          -0.45           5.87
#
#     release_extension  release_pos_y  plate_-x  plate_x  plate_z type  balls  \
# 0                 6.5          54.03      0.69    -0.69     2.83    X      1
# 4                 6.3          54.15      0.31    -0.31     2.80    X      1
# 6                 6.2          54.30      0.69    -0.69     0.83    S      0
# 9                 6.5          53.98      0.26    -0.26     1.78    X      0
# 12                6.4          54.14     -0.98     0.98     1.12    S      0
# 18                6.3          54.23     -0.01     0.01     2.23    X      1
# 22                6.7          53.81      0.36    -0.36     1.26    S      1
# 27                6.6          53.86      0.10    -0.10     1.94    X      0
# 28                6.7          53.80     -0.67     0.67     2.62    X      1
# 30                6.7          53.84     -0.91     0.91     2.50    X      0
#
#     strikes pitch_count stand      bb_type    description     events  \
# 0         2         1-2     R  ground_ball  hit_into_play  field_out
# 4         0         1-0     L  ground_ball  hit_into_play  field_out
# 6         2         0-2     L          NaN         strike  field_out
# 9         2         0-2     R        popup  hit_into_play  field_out
# 12        2         0-2     R          NaN         strike  field_out
# 18        2         1-2     L   line_drive  hit_into_play  field_out
# 22        2         1-2     L          NaN         strike  field_out
# 27        0         0-0     R     fly_ball  hit_into_play  field_out
# 28        0         1-0     L  ground_ball  hit_into_play  field_out
# 30        2         0-2     R  ground_ball  hit_into_play  field_out
#
#     hit_distance_sc  exit_velo  launch_angle  launch_speed_angle    xba  \
# 0              13.0       95.2         -13.0                 2.0  0.174
# 4               9.0       93.3         -18.0                 2.0  0.100
# 6               NaN        NaN           NaN                 NaN    NaN
# 9             140.0       75.3          65.0                 3.0  0.000
# 12              NaN        NaN           NaN                 NaN    NaN
# 18            294.0       96.8          18.0                 4.0  0.409
# 22              NaN        NaN           NaN                 NaN    NaN
# 27            308.0       91.8          29.0                 3.0  0.109
# 28              6.0       76.1         -25.0                 2.0  0.043
# 30              7.0       99.7         -18.0                 2.0  0.177
#
#     xwobacon  woba_value  woba_denom  babip_value  iso_value  at_bat_number  \
# 0      0.158         0.0         1.0          0.0        0.0             61
# 4      0.090         0.0         1.0          0.0        0.0             60
# 6        NaN         0.0         1.0          0.0        0.0             59
# 9      0.000         0.0         1.0          0.0        0.0             58
# 12       NaN         0.0         1.0          0.0        0.0             57
# 18     0.457         0.0         1.0          0.0        0.0             56
# 22       NaN         0.0         1.0          0.0        0.0             55
# 27     0.156         0.0         1.0          0.0        0.0             54
# 28     0.039         0.0         1.0          0.0        0.0             53
# 30     0.171         0.0         1.0          0.0        0.0             52
#
#     pitch_number  inning  inning_topbot  home_score  away_score  \
# 0              4       9              0           5           0
# 4              2       9              0           5           0
# 6              3       9              0           5           0
# 9              3       8              1           5           0
# 12             6       8              1           5           0
# 18             4       8              1           5           0
# 22             5       8              0           5           0
# 27             1       8              0           5           0
# 28             2       8              0           5           0
# 30             3       7              1           5           0
#
#     post_home_score  post_away_score  on_1b  on_2b  on_3b  outs_when_up  \
# 0                 5                0      0      0      0             2
# 4                 5                0      0      0      0             1
# 6                 5                0      0      0      0             0
# 9                 5                0      0      0      0             2
# 12                5                0      0      0      0             1
# 18                5                0      0      0      0             0
# 22                5                0      0      0      0             2
# 27                5                0      0      0      0             1
# 28                5                0      0      0      0             0
# 30                5                0      0      0      0             2
#
#     delta_run_exp  is_strike  is_ball  final_pitch_ab  out_to_end_inning  \
# 0          -0.073          1        0               1                  1
# 4          -0.189          1        0               1                  0
# 6          -0.152          1        0               1                  0
# 9          -0.061          1        0               1                  1
# 12         -0.101          1        0               1                  0
# 18         -0.173          1        0               1                  0
# 22         -0.073          1        0               1                  1
# 27         -0.163          1        0               1                  0
# 28         -0.279          1        0               1                  0
# 30         -0.061          1        0               1                  1
#
#     home_runs  away_runs  runs     re  re_change  re_end_state   re24  \
# 0           0          0     0  0.098     -0.098         0.000 -0.098
# 4           0          0     0  0.254     -0.156         0.098 -0.156
# 6           0          0     0  0.481     -0.227         0.254 -0.227
# 9           0          0     0  0.098     -0.098         0.000 -0.098
# 12          0          0     0  0.254     -0.156         0.098 -0.156
# 18          0          0     0  0.481     -0.227         0.254 -0.227
# 22          0          0     0  0.098     -0.098         0.000 -0.098
# 27          0          0     0  0.254     -0.156         0.098 -0.156
# 28          0          0     0  0.481     -0.227         0.254 -0.227
# 30          0          0     0  0.098     -0.098         0.000 -0.098
#
#     lin_weight_above_avg  lin_weight_above_outs  woba_scale  \
# 0                  -0.25                    0.0       1.209
# 4                  -0.25                    0.0       1.209
# 6                  -0.25                    0.0       1.209
# 9                  -0.25                    0.0       1.209
# 12                 -0.25                    0.0       1.209
# 18                 -0.25                    0.0       1.209
# 22                 -0.25                    0.0       1.209
# 27                 -0.25                    0.0       1.209
# 28                 -0.25                    0.0       1.209
# 30                 -0.25                    0.0       1.209
#
#     final_lin_weights  count_woba_value   wraa  value_change  value_after
# 0                 0.0             0.223 -0.067        -0.171       -0.238
# 4                 0.0             0.355  0.035        -0.035        0.000
# 6                 0.0             0.196 -0.087        -0.150       -0.237
# 9                 0.0             0.196 -0.087        -0.150       -0.237
# 12                0.0             0.196 -0.087        -0.150       -0.237
# 18                0.0             0.223 -0.067        -0.171       -0.238
# 22                0.0             0.223 -0.067        -0.171       -0.238
# 27                0.0             0.310  0.000        -0.037       -0.037
# 28                0.0             0.355  0.035        -0.035        0.000
# 30                0.0             0.196 -0.087        -0.150       -0.237

# %%
re.head()
# Out:
#    on_1b  on_2b  on_3b  outs_when_up     re
# 0      0      0      0             0  0.481
# 1      1      0      0             0  0.859
# 2      0      1      0             0  1.100
# 3      1      1      0             0  1.437
# 4      0      0      1             0  1.350

# %%
woba_value.head()
# Out:
#   pitch_count  count_woba_value   wraa  is_strike  is_ball  value_change
# 0         0-0             0.310  0.000          1        0        -0.037
# 1         0-0             0.310  0.000          0        1         0.032
# 2         0-1             0.262 -0.037          1        0        -0.051
# 3         0-1             0.262 -0.037          0        1         0.024
# 4         0-2             0.196 -0.087          1        0        -0.150

# %%
mlb = pd.read_csv('../data/mlbraw.csv', index_col = [0])
mlb.to_csv('../data/mlbraw.csv')

pd.set_option('max_columns', None)
print(mlb.shape)
mlb.head(10)
# Out:
# (8692, 90)
#              game_date  release_speed  release_pos_x  release_pos_z  \
# pitch_type
# FF          2020-08-01           93.4           1.42           6.34
# CH          2020-08-01           85.7           1.44           5.93
# FF          2020-08-01           94.2           1.08           6.24
# FF          2020-08-01           94.6           1.49           6.15
# FF          2020-08-01           95.1           1.21           6.25
# FF          2020-08-01           94.6           1.37           6.25
# FF          2020-08-01           97.4          -1.11           5.82
# FF          2020-08-01           96.1          -1.12           5.69
# CH          2020-08-01           86.4          -1.21           5.70
# FF          2020-08-01           92.8          -1.10           5.72
#
#              player_name  batter  pitcher     events      description  zone  \
# pitch_type
# FF          Urías, Julio  606466   628711  field_out    hit_into_play   5.0
# CH          Urías, Julio  545121   628711       walk     blocked_ball  14.0
# FF          Urías, Julio  516782   628711     single    hit_into_play   5.0
# FF          Urías, Julio  500871   628711     single    hit_into_play   5.0
# FF          Urías, Julio  572233   628711  strikeout  swinging_strike  13.0
# FF          Urías, Julio  444482   628711  strikeout  swinging_strike   6.0
# FF          Weaver, Luke  571970   596133  strikeout  swinging_strike   2.0
# FF          Weaver, Luke  605141   596133     double    hit_into_play   8.0
# CH          Weaver, Luke  608369   596133  field_out    hit_into_play  13.0
# FF          Weaver, Luke  457759   596133  field_out    hit_into_play   7.0
#
#            stand p_throws home_team away_team type  hit_location      bb_type  \
# pitch_type
# FF             R        L       ARI       LAD    X           6.0  ground_ball
# CH             R        L       ARI       LAD    B           NaN          NaN
# FF             R        L       ARI       LAD    X           7.0   line_drive
# FF             R        L       ARI       LAD    X           8.0  ground_ball
# FF             R        L       ARI       LAD    S           2.0          NaN
# FF             L        L       ARI       LAD    S           2.0          NaN
# FF             L        R       ARI       LAD    S           2.0          NaN
# FF             R        R       ARI       LAD    X           9.0   line_drive
# CH             L        R       ARI       LAD    X           1.0  ground_ball
# FF             R        R       ARI       LAD    X           8.0     fly_ball
#
#             balls  strikes  game_year  pfx_x  pfx_z  plate_x  plate_z  \
# pitch_type
# FF              1        0       2020   0.22   1.58    -0.23     2.73
# CH              3        2       2020   1.34   0.85     0.02     0.49
# FF              3        1       2020   0.12   1.63    -0.26     2.44
# FF              0        2       2020   0.42   1.54    -0.22     2.45
# FF              3        2       2020   0.34   1.47    -1.33     2.11
# FF              2        2       2020   0.19   1.58     0.55     2.75
# FF              1        2       2020  -0.66   1.43    -0.15     3.36
# FF              3        2       2020  -0.51   1.55     0.07     1.95
# CH              0        1       2020  -1.19   1.01    -0.42     1.41
# FF              0        1       2020  -0.95   1.36    -0.45     1.81
#
#                on_3b     on_2b     on_1b  outs_when_up  inning inning_topbot  \
# pitch_type
# FF               NaN       NaN       NaN             0       1           Bot
# CH               NaN       NaN       NaN             1       1           Bot
# FF               NaN       NaN  545121.0             1       1           Bot
# FF               NaN  545121.0  516782.0             1       1           Bot
# FF               NaN  516782.0  500871.0             1       1           Bot
# FF               NaN  516782.0  500871.0             2       1           Bot
# FF               NaN       NaN       NaN             0       1           Top
# FF               NaN       NaN       NaN             1       1           Top
# CH               NaN  605141.0       NaN             1       1           Top
# FF          605141.0       NaN       NaN             2       1           Top
#
#               hc_x    hc_y  fielder_2       vx0         vy0       vz0  \
# pitch_type
# FF          119.30  166.55     669257 -4.675694 -135.773799 -6.874367
# CH             NaN     NaN     669257 -6.020264 -124.380348 -8.175028
# FF           55.04   84.42     669257 -3.717263 -136.925868 -7.652756
# FF          121.26  123.88     669257 -5.326476 -137.505209 -7.269481
# FF             NaN     NaN     669257 -7.325611 -138.035108 -8.351507
# FF             NaN     NaN     669257 -2.520725 -137.475732 -6.819991
# FF             NaN     NaN     608348  4.093093 -141.737634 -4.333866
# FF          168.68   47.66     608348  4.284104 -139.713886 -7.791299
# CH          141.56  183.50     608348  4.297433 -125.694396 -6.017496
# FF          122.16   33.88     608348  3.739578 -134.919553 -7.108615
#
#                    ax         ay         az  sz_top  sz_bot  hit_distance_sc  \
# pitch_type
# FF           3.868106  33.537863 -11.299569    3.41    1.56             21.0
# CH          15.179642  26.595959 -21.796241    3.36    1.63              NaN
# FF           2.381237  33.446765 -10.212867    3.41    1.56            275.0
# FF           6.544901  34.162442 -11.197421    3.30    1.50             78.0
# FF           6.025315  32.893259 -11.671439    3.37    1.53              NaN
# FF           2.969181  34.377458 -10.841372    3.41    1.56              NaN
# FF          -9.913721  34.189966 -12.144922    3.37    1.53              NaN
# FF          -7.650463  33.196526 -10.250681    3.29    1.49            370.0
# CH         -13.487570  26.012332 -20.453830    3.55    1.63             89.0
# FF         -12.407455  30.974500 -14.238539    3.32    1.51            388.0
#
#             launch_speed  launch_angle  effective_speed  release_spin_rate  \
# pitch_type
# FF                  82.7          -6.0             91.9             2489.0
# CH                   NaN           NaN             84.9             1940.0
# FF                  88.0          21.0             93.1             2425.0
# FF                  87.7           4.0             93.2             2517.0
# FF                   NaN           NaN             93.8             2444.0
# FF                   NaN           NaN             93.2             2432.0
# FF                   NaN           NaN             96.8             2563.0
# FF                 102.6          18.0             95.5             2498.0
# CH                  81.0           7.0             86.2             1780.0
# FF                  96.3          33.0             92.2             2389.0
#
#             release_extension  game_pk  pitcher_1  fielder_2_1  release_pos_y  \
# pitch_type
# FF                        5.7   630100     628711       669257          54.79
# CH                        6.1   630100     628711       669257          54.44
# FF                        6.0   630100     628711       669257          54.54
# FF                        5.8   630100     628711       669257          54.73
# FF                        5.8   630100     628711       669257          54.67
# FF                        5.8   630100     628711       669257          54.69
# FF                        6.1   630100     596133       608348          54.40
# FF                        6.1   630100     596133       608348          54.36
# CH                        6.2   630100     596133       608348          54.31
# FF                        6.1   630100     596133       608348          54.38
#
#             estimated_ba_using_speedangle  estimated_woba_using_speedangle  \
# pitch_type
# FF                                  0.153                            0.141
# CH                                    NaN                              NaN
# FF                                  0.367                            0.347
# FF                                  0.393                            0.373
# FF                                    NaN                              NaN
# FF                                    NaN                              NaN
# FF                                    NaN                              NaN
# FF                                  0.513                            0.597
# CH                                  0.347                            0.312
# FF                                  0.260                            0.485
#
#             woba_value  woba_denom  babip_value  iso_value  \
# pitch_type
# FF                0.00         1.0          0.0        0.0
# CH                0.70         1.0          0.0        0.0
# FF                0.90         1.0          1.0        0.0
# FF                0.90         1.0          1.0        0.0
# FF                0.00         1.0          0.0        0.0
# FF                0.00         1.0          0.0        0.0
# FF                0.00         1.0          0.0        0.0
# FF                1.25         1.0          1.0        1.0
# CH                0.00         1.0          0.0        0.0
# FF                0.00         1.0          0.0        0.0
#
#             launch_speed_angle  at_bat_number  pitch_number       pitch_name  \
# pitch_type
# FF                         2.0              5             2  4-Seam Fastball
# CH                         NaN              6             6         Changeup
# FF                         3.0              7             5  4-Seam Fastball
# FF                         2.0              8             3  4-Seam Fastball
# FF                         NaN              9             7  4-Seam Fastball
# FF                         NaN             10             5  4-Seam Fastball
# FF                         NaN              1             4  4-Seam Fastball
# FF                         5.0              2             6  4-Seam Fastball
# CH                         2.0              3             2         Changeup
# FF                         5.0              4             2  4-Seam Fastball
#
#             home_score  away_score  bat_score  fld_score  post_away_score  \
# pitch_type
# FF                   0           0          0          0                0
# CH                   0           0          0          0                0
# FF                   0           0          0          0                0
# FF                   0           0          0          0                0
# FF                   1           0          1          0                0
# FF                   1           0          1          0                0
# FF                   0           0          0          0                0
# FF                   0           0          0          0                0
# CH                   0           0          0          0                0
# FF                   0           0          0          0                0
#
#             post_home_score  post_bat_score  post_fld_score  \
# pitch_type
# FF                        0               0               0
# CH                        0               0               0
# FF                        0               0               0
# FF                        1               1               0
# FF                        1               1               0
# FF                        1               1               0
# FF                        0               0               0
# FF                        0               0               0
# CH                        0               0               0
# FF                        0               0               0
#
#            if_fielding_alignment of_fielding_alignment  spin_axis  \
# pitch_type
# FF                      Standard              Standard      158.0
# CH                      Standard              Standard      128.0
# FF                 Infield shift              Standard      156.0
# FF                      Standard              Standard      156.0
# FF                 Infield shift              Standard      155.0
# FF                      Standard              Standard      157.0
# FF                 Infield shift              Standard      201.0
# FF                      Standard              Standard      206.0
# CH                     Strategic              Standard      216.0
# FF                      Standard              Standard      209.0
#
#             delta_home_win_exp  delta_run_exp       des2  final_pitch_game  \
# pitch_type
# FF                      -0.021         -0.291  field_out                 0
# CH                       0.024          0.226       walk                 0
# FF                       0.035          0.364     single                 0
# FF                       0.096          1.147     single                 0
# FF                      -0.036         -0.551  strikeout                 0
# FF                      -0.037         -0.370  strikeout                 0
# FF                       0.022         -0.181  strikeout                 0
# FF                      -0.041          0.387     double                 0
# CH                       0.030         -0.282  field_out                 0
# FF                       0.036         -0.307  field_out                 0
#
#             final_pitch_at_bat  runs_scored_on_pitch  bat_score_after  \
# pitch_type
# FF                           1                     0                0
# CH                           1                     0                0
# FF                           1                     0                0
# FF                           1                     1                1
# FF                           1                     0                1
# FF                           1                     0                1
# FF                           1                     0                0
# FF                           1                     0                0
# CH                           1                     0                0
# FF                           1                     0                0
#
#             final_pitch_inning  bat_score_start_inning  bat_score_end_inning  \
# pitch_type
# FF                           0                       0                     1
# CH                           0                       0                     1
# FF                           0                       0                     1
# FF                           0                       0                     1
# FF                           0                       0                     1
# FF                           1                       0                     1
# FF                           0                       0                     0
# FF                           0                       0                     0
# CH                           0                       0                     0
# FF                           1                       0                     0
#
#             cum_runs_in_inning  runs_to_end_inning     base_out_state  \
# pitch_type
# FF                           0                   1    0  outs,  _ _ _
# CH                           0                   1    1  outs,  _ _ _
# FF                           0                   1   1  outs,  1b _ _
# FF                           3                   1  1  outs,  1b 2b _
# FF                           3                   0  1  outs,  1b 2b _
# FF                           3                   0  2  outs,  1b 2b _
# FF                           0                   0    0  outs,  _ _ _
# FF                           0                   0    1  outs,  _ _ _
# CH                           0                   0   1  outs,  _ 2b _
# FF                           0                   0   2  outs,  _ _ 3b
#
#               avg_re next_base_out_state  next_avg_re  change_re      re24
# pitch_type
# FF          0.504171     1  outs,  _ _ _     0.279230  -0.224941 -0.224941
# CH          0.279230    1  outs,  1b _ _     0.589391   0.310161  0.310161
# FF          0.589391   1  outs,  1b 2b _     0.891192   0.301801  0.301801
# FF          0.891192   1  outs,  1b 2b _     0.891192   0.000000  1.000000
# FF          0.891192   2  outs,  1b 2b _     0.444444  -0.446747 -0.446747
# FF          0.444444                 NaN     0.000000  -0.444444 -0.444444
# FF          0.504171     1  outs,  _ _ _     0.279230  -0.224941 -0.224941
# FF          0.279230    1  outs,  _ 2b _     0.656805   0.377575  0.377575
# CH          0.656805    2  outs,  _ _ 3b     0.420455  -0.236350 -0.236350
# FF          0.420455                 NaN     0.000000  -0.420455 -0.420455
