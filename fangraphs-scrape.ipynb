# %%
import pybaseball
from pybaseball import statcast, statcast_pitcher_pitch_arsenal, statcast_pitcher_arsenal_stats

# %%
data4 = pybaseball.pitching_stats(2021, qual = 1)
print(data4.shape)
data4.head()
# Out:
# (885, 334)
#       IDfg  Season            Name   Team  Age   W   L  WAR   ERA   G  ...  \
# 109  19361    2021   Corbin Burnes    MIL   26  11   5  7.5  2.43  28  ...
# 148  10310    2021    Zack Wheeler    PHI   31  14  10  7.3  2.78  32  ...
# 326   9132    2021  Nathan Eovaldi    BOS   31  11   9  5.6  3.75  32  ...
# 116  19374    2021  Walker Buehler    LAD   26  16   4  5.5  2.47  33  ...
# 115   3137    2021    Max Scherzer  - - -   36  15   4  5.4  2.46  30  ...
#
#        LA  Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  \
# 109   8.4       12    0.031  114.2      117     0.305     383  0.172  0.338
# 148   8.4       25    0.046  118.6      156     0.285     548  0.156  0.280
# 326  12.8       33    0.063  115.6      191     0.362     527  0.173  0.299
# 116  11.1       37    0.068  114.4      201     0.369     545  0.181  0.296
# 115  19.3       33    0.080  113.3      141     0.343     411  0.157  0.316
#
#      xERA
# 109  2.00
# 148  2.79
# 326  3.37
# 116  3.10
# 115  2.90
#
# [5 rows x 334 columns]
