# %%
import pybaseball
from pybaseball import statcast, statcast_pitcher_pitch_arsenal, statcast_pitcher_arsenal_stats

# %%
data = statcast_pitcher_pitch_arsenal(2021, arsenal_type = 'avg_speed', minP = 0)
print(data.shape)
data.head()
# Out:
# (909, 11)
#   last_name  first_name  pitcher  ff_avg_speed  si_avg_speed  fc_avg_speed  \
# 0     Clase    Emmanuel   661403         100.7           NaN         100.2
# 1     Hicks      Jordan   663855         100.5          99.2          87.2
# 2     Muñoz      Andrés   662253          99.6           NaN           NaN
# 3  Graterol     Brusdar   660813          99.5         100.0          95.4
# 4      Gose     Anthony   543238          99.3           NaN           NaN
#
#    sl_avg_speed  ch_avg_speed  cu_avg_speed  fs_avg_speed  kn_avg_speed
# 0          91.9           NaN           NaN           NaN           NaN
# 1          83.5          90.2           NaN           NaN           NaN
# 2          82.2           NaN           NaN           NaN           NaN
# 3          88.1           NaN           NaN           NaN           NaN
# 4          84.7           NaN           NaN           NaN           NaN

# %%
data2 = statcast_pitcher_pitch_arsenal(2021, arsenal_type = 'avg_spin', minP = 0)
print(data2.shape)
data2.head()
# Out:
# (909, 11)
#   last_name  first_name  pitcher  ff_avg_spin  si_avg_spin  fc_avg_spin  \
# 0     Clase    Emmanuel   661403       2546.0          NaN       2579.0
# 1     Hicks      Jordan   663855       2041.0       2011.0       2382.0
# 2     Muñoz      Andrés   662253       2291.0          NaN          NaN
# 3  Graterol     Brusdar   660813       2115.0       2065.0       2352.0
# 4      Gose     Anthony   543238       2439.0          NaN          NaN
#
#    sl_avg_spin  ch_avg_spin  cu_avg_spin  fs_avg_spin  kn_avg_spin
# 0       2550.0          NaN          NaN          NaN          NaN
# 1       2379.0        964.0          NaN          NaN          NaN
# 2       2230.0          NaN          NaN          NaN          NaN
# 3       2521.0          NaN          NaN          NaN          NaN
# 4       2459.0          NaN          NaN          NaN          NaN

# %%
data3 = statcast_pitcher_arsenal_stats(2021, minPA = 0)
pd.set_option('max_columns', None)
print(data3.shape)
data3.head()
# Out:
# (3325, 21)
#   last_name  first_name  player_id team_name_alt pitch_type pitch_name  \
# 0       Ray      Robbie     592662           TOR         FF   4-Seamer
# 1    Manaea        Sean     640455           OAK       SIFT     Sinker
# 2   Gausman       Kevin     592332            SF         FF   4-Seamer
# 3     Mahle       Tyler     641816           CIN         FF   4-Seamer
# 4    Burnes      Corbin     669203           MIL         FC     Cutter
#
#    run_value_per_100  run_value  pitches  pitch_usage   pa     ba    slg  \
# 0               -1.2        -22     1866         59.4  471  0.222  0.431
# 1               -0.1         -2     1787         60.0  438  0.273  0.463
# 2               -0.6        -10     1583         52.7  421  0.257  0.416
# 3               -0.6        -10     1697         53.1  387  0.236  0.435
# 4               -1.6        -21     1356         52.3  364  0.237  0.328
#
#     woba  whiff_percent  k_percent  put_away  est_ba  est_slg  est_woba  \
# 0  0.318           24.0       24.6      21.0   0.243    0.457     0.328
# 1  0.343           25.0       26.0      19.3   0.266    0.470     0.340
# 2  0.335           19.5       19.2      19.5   0.278    0.485     0.352
# 3  0.337           26.9       34.6      21.4   0.215    0.365     0.308
# 4  0.290           32.1       32.1      31.0   0.199    0.291     0.255
#
#    hard_hit_percent
# 0              43.2
# 1              45.2
# 2              44.8
# 3              41.2
# 4              32.1

# %%
#pd.merge()

# %%
data4 = pybaseball.pitching_stats(2021)
print(data4.shape)
data4.head()
# Out:
# (39, 334)
#      IDfg  Season            Name   Team  Age   W   L  WAR   ERA   G  GS  CG  \
# 0   19361    2021   Corbin Burnes    MIL   26  11   5  7.5  2.43  28  28   0
# 4   10310    2021    Zack Wheeler    PHI   31  14  10  7.3  2.78  32  32   3
# 24   9132    2021  Nathan Eovaldi    BOS   31  11   9  5.6  3.75  32  32   0
# 2   19374    2021  Walker Buehler    LAD   26  16   4  5.5  2.47  33  33   0
# 1    3137    2021    Max Scherzer  - - -   36  15   4  5.4  2.46  30  30   1
#
#     ShO  SV  BS     IP  TBF    H   R  ER  HR  BB  IBB  HBP  WP  BK   SO   GB  \
# 0     0   0   0  167.0  657  123  47  45   7  34    0    6   5   0  234  185
# 4     2   0   0  213.1  849  169  72  66  16  46    1    8   6   0  247  268
# 24    0   0   0  182.1  764  182  81  76  15  35    2    7   6   0  195  220
# 2     0   0   0  207.2  815  149  61  57  19  52    2    6   5   0  212  238
# 1     0   0   0  179.1  693  119  53  49  23  36    0   10   2   0  236  136
#
#      FB   LD  IFFB  Balls  Strikes  Pitches   RS  IFH  BU  BUH    K/9  BB/9  \
# 0   115   79     9    872     1722     2594   85   17   4    1  12.61  1.83
# 4   148  122    19   1041     2164     3205   87   11  10    1  10.42  1.94
# 24  182  122    21    908     2019     2927  118   21   3    0   9.63  1.73
# 2   189  106    22   1032     2120     3152  123   13  12    3   9.19  2.25
# 1   196   74    19    950     1871     2821  106   12   5    1  11.84  1.81
#
#     K/BB   H/9  HR/9    AVG  WHIP  BABIP   LOB%   FIP  GB/FB    LD%    GB%  \
# 0   6.88  6.63  0.38  0.199  0.94  0.309  0.757  1.63   1.61  0.208  0.488
# 4   5.37  7.13  0.68  0.213  1.01  0.288  0.753  2.59   1.81  0.227  0.498
# 24  5.57  8.98  0.74  0.252  1.19  0.326  0.704  2.79   1.21  0.233  0.420
# 2   4.08  6.46  0.82  0.197  0.97  0.247  0.809  3.16   1.26  0.199  0.447
# 1   6.56  5.97  1.15  0.184  0.86  0.247  0.843  2.97   0.69  0.182  0.335
#
#       FB%  IFFB%  HR/FB   IFH%  BUH%  Starting  Start-IP  Relieving  \
# 0   0.303  0.078  0.061  0.092  0.25      65.4     167.0        NaN
# 4   0.275  0.128  0.108  0.041  0.10      65.6     213.1        NaN
# 24  0.347  0.115  0.082  0.095  0.00      52.2     182.1        NaN
# 2   0.355  0.116  0.101  0.055  0.25      51.4     207.2        NaN
# 1   0.483  0.097  0.117  0.088  0.20      49.1     179.1        NaN
#
#     Relief-IP   RAR Dollars  tERA  xFIP   WPA   -WPA   +WPA   RE24   REW  \
# 0         NaN  65.4   $59.8  1.96  2.30  3.31  -9.18  12.49  34.93  3.55
# 4         NaN  65.6   $58.1  3.09  2.84  3.62 -12.53  16.14  39.57  4.03
# 24        NaN  52.2   $44.9  3.47  3.48  1.86 -11.81  13.67  21.73  2.02
# 2         NaN  51.4   $43.7  3.22  3.57  3.84 -11.08  14.92  43.32  4.51
# 1         NaN  49.1   $42.9  2.87  3.24  4.37  -8.62  12.98  38.94  3.98
#
#      pLI  inLI  gmLI  exLI  Pulls  WPA/LI  Clutch  FB% 2   FBv    SL%   SLv  \
# 0   1.00  0.97  0.87  1.37     28    4.44   -1.13  0.108  96.9  0.090  88.1
# 4   1.01  0.99  0.87  1.25     29    4.41   -0.81  0.607  97.1  0.249  91.6
# 24  0.96  0.91  0.87  1.14     32    2.26   -0.31  0.424  96.9  0.137  85.8
# 2   0.94  0.90  0.87  1.08     33    3.37    0.71  0.517  95.4  0.145  85.1
# 1   0.92  0.93  0.86  1.04     29    4.16    0.58  0.468  94.3  0.191  85.9
#
#       CT%   CTv    CB%   CBv    CH%   CHv    SF%   SFv  KN%  KNv    XX%  PO%  \
# 0   0.522  95.3  0.184  81.3  0.098  90.7    NaN   NaN  NaN  NaN    NaN  NaN
# 4     NaN   NaN  0.107  81.5  0.032  90.4  0.004  90.9  NaN  NaN  0.001  NaN
# 24  0.125  92.5  0.188  78.6    NaN   NaN  0.127  88.0  NaN  NaN  0.003  NaN
# 2   0.157  91.7  0.132  80.2  0.049  91.5    NaN   NaN  NaN  NaN  0.003  NaN
# 1   0.093  90.1  0.098  76.9  0.149  85.0    NaN   NaN  NaN  NaN    NaN  NaN
#
#      wFB   wSL   wCT   wCB  wCH  wSF  wKN  wFB/C  wSL/C  wCT/C  wCB/C  wCH/C  \
# 0   -2.4   7.0  24.2  13.3  0.7  NaN  NaN  -0.85   2.99   1.79   2.79   0.27
# 4   26.0  12.6   NaN   2.5 -0.2 -0.1  NaN   1.33   1.58    NaN   0.72  -0.15
# 24   0.1   0.3   0.4   6.9  NaN -0.2  NaN   0.01   0.07   0.10   1.26    NaN
# 2   22.9   5.9   6.6   2.3  4.6  NaN  NaN   1.40   1.29   1.33   0.55   3.01
# 1   19.9  13.2  -0.4  -0.2  5.8  NaN  NaN   1.51   2.45  -0.13  -0.09   1.38
#
#     wSF/C  wKN/C  O-Swing%  Z-Swing%  Swing%  O-Contact%  Z-Contact%  \
# 0     NaN    NaN     0.378     0.655   0.485       0.489       0.811
# 4   -0.63    NaN     0.352     0.720   0.514       0.648       0.829
# 24  -0.05    NaN     0.338     0.710   0.515       0.595       0.840
# 2     NaN    NaN     0.331     0.686   0.488       0.600       0.862
# 1     NaN    NaN     0.337     0.720   0.503       0.516       0.787
#
#     Contact%  Zone%  F-Strike%  SwStr%  HLD  SD  MD  ERA-  FIP-  xFIP-     K%  \
# 0      0.658  0.389      0.624   0.166    0   0   0    57    38     54  0.356
# 4      0.760  0.439      0.668   0.124    0   0   0    66    59     66  0.291
# 24     0.756  0.476      0.653   0.126    0   0   0    83    66     81  0.255
# 2      0.763  0.440      0.654   0.116    0   0   0    61    74     84  0.260
# 1      0.685  0.435      0.641   0.159    0   0   0    59    69     76  0.341
#
#       BB%  SIERA  RS/9   E-F  FA% (sc)  FT% (sc)  FC% (sc)  FS% (sc)  \
# 0   0.052   2.61  4.58  0.79     0.015       NaN     0.523       NaN
# 4   0.054   3.18  3.67  0.20     0.425       NaN       NaN       NaN
# 24  0.046   3.60  5.82  0.96     0.423       NaN     0.125     0.127
# 2   0.064   3.73  5.33 -0.69     0.445       NaN     0.162       NaN
# 1   0.052   2.90  5.32 -0.52     0.467       NaN     0.090       NaN
#
#     FO% (sc)  SI% (sc)  SL% (sc)  CU% (sc)  KC% (sc)  EP% (sc)  CH% (sc)  \
# 0        NaN     0.091     0.092     0.183       NaN       NaN     0.096
# 4        NaN     0.182     0.249     0.106       NaN       NaN     0.038
# 24       NaN       NaN     0.137     0.188       NaN       NaN       NaN
# 2        NaN     0.074     0.138       NaN     0.132       NaN     0.048
# 1        NaN       NaN     0.196     0.098       NaN       NaN     0.149
#
#     SC% (sc)  KN% (sc)  UN% (sc)  vFA (sc)  vFT (sc)  vFC (sc)  vFS (sc)  \
# 0        NaN       NaN       NaN      96.4       NaN      95.2       NaN
# 4        NaN       NaN       NaN      97.2       NaN       NaN       NaN
# 24       NaN       NaN       NaN      96.8       NaN      92.5      87.9
# 2        NaN       NaN       NaN      95.3       NaN      91.6       NaN
# 1        NaN       NaN       NaN      94.3       NaN      90.2       NaN
#
#     vFO (sc)  vSI (sc)  vSL (sc)  vCU (sc)  vKC (sc)  vEP (sc)  vCH (sc)  \
# 0        NaN      96.9      88.0      81.2       NaN       NaN      90.7
# 4        NaN      96.7      91.5      81.5       NaN       NaN      90.6
# 24       NaN       NaN      85.8      78.5       NaN       NaN       NaN
# 2        NaN      95.3      84.9       NaN      80.1       NaN      91.5
# 1        NaN       NaN      85.9      76.9       NaN       NaN      85.0
#
#     vSC (sc)  vKN (sc)  FA-X (sc)  FT-X (sc)  FC-X (sc)  FS-X (sc)  FO-X (sc)  \
# 0        NaN       NaN       -3.4        NaN        2.1        NaN        NaN
# 4        NaN       NaN       -4.9        NaN        NaN        NaN        NaN
# 24       NaN       NaN       -7.7        NaN       -0.4       -6.9        NaN
# 2        NaN       NaN       -2.0        NaN        3.0        NaN        NaN
# 1        NaN       NaN       -7.0        NaN       -1.7        NaN        NaN
#
#     SI-X (sc)  SL-X (sc)  CU-X (sc)  KC-X (sc)  EP-X (sc)  CH-X (sc)  \
# 0        -6.9        3.9        6.3        NaN        NaN       -8.0
# 4        -9.3        0.7        5.1        NaN        NaN       -8.2
# 24        NaN        2.7        5.0        NaN        NaN        NaN
# 2        -7.9        7.6        NaN        6.0        NaN       -7.7
# 1         NaN        0.6        6.8        NaN        NaN       -9.5
#
#     SC-X (sc)  KN-X (sc)  FA-Z (sc)  FT-Z (sc)  FC-Z (sc)  FS-Z (sc)  \
# 0         NaN        NaN        8.2        NaN        6.7        NaN
# 4         NaN        NaN        9.3        NaN        NaN        NaN
# 24        NaN        NaN        8.4        NaN        6.8        1.3
# 2         NaN        NaN       10.4        NaN        4.8        NaN
# 1         NaN        NaN        9.3        NaN        5.2        NaN
#
#     FO-Z (sc)  SI-Z (sc)  SL-Z (sc)  CU-Z (sc)  KC-Z (sc)  EP-Z (sc)  \
# 0         NaN        7.3        0.3       -4.2        NaN        NaN
# 4         NaN        6.8        3.5       -6.4        NaN        NaN
# 24        NaN        NaN        1.4       -6.0        NaN        NaN
# 2         NaN        7.8        0.6        NaN       -8.5        NaN
# 1         NaN        NaN        2.9       -4.6        NaN        NaN
#
#     CH-Z (sc)  SC-Z (sc)  KN-Z (sc)  wFA (sc)  wFT (sc)  wFC (sc)  wFS (sc)  \
# 0         4.7        NaN        NaN      -2.3       NaN      26.2       NaN
# 4         6.1        NaN        NaN      17.0       NaN       NaN       NaN
# 24        NaN        NaN        NaN      -0.2       NaN       1.2      -0.1
# 2         3.3        NaN        NaN      18.5       NaN       6.7       NaN
# 1         2.4        NaN        NaN      20.0       NaN      -1.9       NaN
#
#     wFO (sc)  wSI (sc)  wSL (sc)  wCU (sc)  wKC (sc)  wEP (sc)  wCH (sc)  \
# 0        NaN      -0.4       7.1      14.1       NaN       NaN       0.6
# 4        NaN      11.9      12.2       2.5       NaN       NaN      -1.5
# 24       NaN       NaN       0.1       8.1       NaN       NaN       NaN
# 2        NaN       4.1       6.4       NaN       2.8       NaN       5.1
# 1        NaN       NaN      15.4      -0.1       NaN       NaN       5.9
#
#     wSC (sc)  wKN (sc)  wFA/C (sc)  wFT/C (sc)  wFC/C (sc)  wFS/C (sc)  \
# 0        NaN       NaN       -5.68         NaN        1.93         NaN
# 4        NaN       NaN        1.25         NaN         NaN         NaN
# 24       NaN       NaN       -0.02         NaN        0.32       -0.02
# 2        NaN       NaN        1.32         NaN        1.31         NaN
# 1        NaN       NaN        1.53         NaN       -0.73         NaN
#
#     wFO/C (sc)  wSI/C (sc)  wSL/C (sc)  wCU/C (sc)  wKC/C (sc)  wEP/C (sc)  \
# 0          NaN       -0.16        2.98        2.98         NaN         NaN
# 4          NaN        2.04        1.52        0.74         NaN         NaN
# 24         NaN         NaN        0.03        1.48         NaN         NaN
# 2          NaN        1.75        1.47         NaN        0.68         NaN
# 1          NaN         NaN        2.80       -0.03         NaN         NaN
#
#     wCH/C (sc)  wSC/C (sc)  wKN/C (sc)  O-Swing% (sc)  Z-Swing% (sc)  \
# 0         0.25         NaN         NaN          0.329          0.645
# 4        -1.19         NaN         NaN          0.280          0.705
# 24         NaN         NaN         NaN          0.316          0.663
# 2         3.36         NaN         NaN          0.286          0.670
# 1         1.41         NaN         NaN          0.302          0.683
#
#     Swing% (sc)  O-Contact% (sc)  Z-Contact% (sc)  Contact% (sc)  Zone% (sc)  \
# 0         0.485            0.374            0.806          0.658       0.495
# 4         0.514            0.526            0.834          0.759       0.551
# 24        0.515            0.520            0.840          0.756       0.572
# 2         0.488            0.526            0.851          0.761       0.527
# 1         0.504            0.445            0.776          0.683       0.531
#
#     Pace  RA9-WAR  BIP-Wins  LOB-Wins  FDP-Wins  Age Rng  K-BB%  Pull%  Cent%  \
# 0    NaN      6.3      -0.7      -0.5      -1.2  26 - 26  0.304  0.402  0.360
# 4    NaN      6.7       0.0      -0.5      -0.5  31 - 31  0.237  0.354  0.372
# 24   NaN      4.2      -1.4       0.0      -1.4  31 - 31  0.209  0.347  0.347
# 2    NaN      7.4       2.0       0.0       1.9  26 - 26  0.196  0.385  0.369
# 1    NaN      6.6       1.4      -0.1       1.3  36 - 36  0.289  0.392  0.348
#
#     Oppo%  Soft%   Med%  Hard%  kwERA   TTO%  CH% (pi)  CS% (pi)  CU% (pi)  \
# 0   0.238  0.204  0.548  0.248   2.50  0.419     0.096       NaN     0.183
# 4   0.274  0.230  0.546  0.224   3.31  0.364     0.017       NaN     0.106
# 24  0.306  0.167  0.562  0.271   3.64  0.321       NaN       NaN     0.188
# 2   0.246  0.174  0.519  0.306   3.80  0.347     0.046       NaN     0.132
# 1   0.260  0.170  0.484  0.345   2.69  0.426     0.149       NaN     0.098
#
#     FA% (pi)  FC% (pi)  FS% (pi)  KN% (pi)  SB% (pi)  SI% (pi)  SL% (pi)  \
# 0      0.014     0.521       NaN       NaN       NaN     0.096     0.090
# 4      0.426       NaN     0.020       NaN       NaN     0.182     0.250
# 24     0.423     0.125     0.127       NaN       NaN       NaN     0.137
# 2      0.445     0.160       NaN       NaN       NaN     0.075     0.141
# 1      0.467     0.095       NaN       NaN       NaN       NaN     0.190
#
#     XX% (pi)  vCH (pi)  vCS (pi)  vCU (pi)  vFA (pi)  vFC (pi)  vFS (pi)  \
# 0        NaN      90.6       NaN      81.2      96.5      95.1       NaN
# 4        NaN      90.8       NaN      81.6      97.3       NaN      90.5
# 24       NaN       NaN       NaN      78.8      97.1      92.7      88.2
# 2        NaN      91.4       NaN      80.2      95.5      91.7       NaN
# 1        NaN      85.1       NaN      77.0      94.5      90.3       NaN
#
#     vKN (pi)  vSB (pi)  vSI (pi)  vSL (pi)  vXX (pi)  CH-X (pi)  CS-X (pi)  \
# 0        NaN       NaN      96.8      87.9       NaN       -8.1        NaN
# 4        NaN       NaN      96.8      91.7       NaN       -8.3        NaN
# 24       NaN       NaN       NaN      86.0       NaN        NaN        NaN
# 2        NaN       NaN      95.3      85.0       NaN       -7.5        NaN
# 1        NaN       NaN       NaN      86.0       NaN       -8.7        NaN
#
#     CU-X (pi)  FA-X (pi)  FC-X (pi)  FS-X (pi)  KN-X (pi)  SB-X (pi)  \
# 0         6.4       -2.8        2.4        NaN        NaN        NaN
# 4         5.6       -4.4        NaN       -7.7        NaN        NaN
# 24        5.7       -7.0        0.3       -6.3        NaN        NaN
# 2         6.3       -1.8        3.4        NaN        NaN        NaN
# 1         7.8       -6.1       -0.3        NaN        NaN        NaN
#
#     SI-X (pi)  SL-X (pi)  XX-X (pi)  CH-Z (pi)  CS-Z (pi)  CU-Z (pi)  \
# 0        -6.8        4.4        NaN        3.2        NaN       -5.8
# 4        -9.1        1.3        NaN        5.2        NaN       -8.1
# 24        NaN        3.5        NaN        NaN        NaN       -7.6
# 2        -7.8        8.2        NaN        2.2        NaN      -10.2
# 1         NaN        1.7        NaN        1.0        NaN       -6.2
#
#     FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  KN-Z (pi)  SB-Z (pi)  SI-Z (pi)  \
# 0         7.9        5.5        NaN        NaN        NaN        6.0
# 4         8.2        NaN        3.9        NaN        NaN        5.5
# 24        7.3        5.6       -0.2        NaN        NaN        NaN
# 2         9.5        3.9        NaN        NaN        NaN        6.7
# 1         8.2        4.0        NaN        NaN        NaN        NaN
#
#     SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  wCU (pi)  wFA (pi)  wFC (pi)  \
# 0        -1.2        NaN       0.6       NaN      14.1       0.5      26.1
# 4         2.3        NaN       1.6       NaN       2.5      16.7       NaN
# 24        0.0        NaN       NaN       NaN       8.1       0.2       0.7
# 2        -0.7        NaN       4.9       NaN       2.8      17.9       8.5
# 1         1.4        NaN       5.9       NaN      -0.1      19.7       0.9
#
#     wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  wSL (pi)  wXX (pi)  wCH/C (pi)  \
# 0        NaN       NaN       NaN      -2.7       6.9       NaN        0.25
# 4       -1.8       NaN       NaN      10.6      12.2       NaN        3.02
# 24      -0.1       NaN       NaN       NaN       0.3       NaN         NaN
# 2        NaN       NaN       NaN       4.3       4.9       NaN        3.33
# 1        NaN       NaN       NaN       NaN      12.9       NaN        1.41
#
#     wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  wFC/C (pi)  wFS/C (pi)  wKN/C (pi)  \
# 0          NaN        2.97        1.37        1.93         NaN         NaN
# 4          NaN        0.74        1.23         NaN       -2.89         NaN
# 24         NaN        1.48        0.01        0.20       -0.02         NaN
# 2          NaN        0.67        1.27        1.67         NaN         NaN
# 1          NaN       -0.03        1.50        0.35         NaN         NaN
#
#     wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  wXX/C (pi)  O-Swing% (pi)  \
# 0          NaN       -1.10        2.96         NaN          0.332
# 4          NaN        1.82        1.53         NaN          0.282
# 24         NaN         NaN        0.08         NaN          0.323
# 2          NaN        1.83        1.11         NaN          0.289
# 1          NaN         NaN        2.41         NaN          0.301
#
#     Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  Z-Contact% (pi)  \
# 0           0.643        0.485            0.393            0.799
# 4           0.694        0.514            0.533            0.831
# 24          0.655        0.515            0.531            0.837
# 2           0.660        0.488            0.523            0.850
# 1           0.676        0.504            0.444            0.775
#
#     Contact% (pi)  Zone% (pi)  Pace (pi)  FRM  K/9+  BB/9+  K/BB+  H/9+  \
# 0           0.658       0.492        NaN  1.4   141     54    262    81
# 4           0.760       0.564        NaN  1.1   116     57    204    87
# 24          0.756       0.578        NaN  0.3   109     53    206   106
# 2           0.760       0.537        NaN  0.6   103     66    155    78
# 1           0.684       0.540        NaN -0.4   132     53    249    73
#
#     HR/9+  AVG+  WHIP+  BABIP+  LOB%+  K%+  BB%+  LD%+  GB%+  FB%+  HR/FB%+  \
# 0      31    84     73     107    105  153    58   100   112    85       44
# 4      55    89     78     100    104  125    61   109   114    77       79
# 24     58   104     91     112     98  111    54   114    99    93       61
# 2      67    83     75      86    112  112    72    95   103    99       73
# 1      94    77     67      86    117  146    59    88    77   135       86
#
#     Pull%+  Cent%+  Oppo%+  Soft%+  Med%+  Hard%+    EV    LA  Barrels  \
# 0      101     102      95     123    107      77  85.5   8.4       12
# 4       89     106     110     139    106      70  84.6   8.4       25
# 24      86     100     122     102    109      84  88.0  12.8       33
# 2       97     105      98     105    101      95  88.2  11.1       37
# 1       98      99     104     103     94     108  87.9  19.3       33
#
#     Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xERA
# 0     0.031  114.2      117     0.305     383  0.172  0.338  2.00
# 4     0.046  118.6      156     0.285     548  0.156  0.280  2.79
# 24    0.063  115.6      191     0.362     527  0.173  0.299  3.37
# 2     0.068  114.4      201     0.369     545  0.181  0.296  3.10
# 1     0.080  113.3      141     0.343     411  0.157  0.316  2.90
