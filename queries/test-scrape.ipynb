# %% [markdown]
# - [x] Pitch Velocity
# - [x] VB
# - [x] HB
# - [ ] Arm Angle
# - [x] Release Extension

# %%
data = pd.read_csv('./data/mlb-pitches.csv')
data.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'], inplace = True) 

font_title = {
    'size': 12,
    'weight': 'bold',
    'verticalalignment': 'center_baseline',
    'horizontalalignment': 'center'
}

pd.set_option('max_columns', None)
print(data.shape)
data.head(3)
# Out:
# (708653, 76)
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2021-10-03           92.3           1.40           6.80
# 1         SL  2021-10-03           80.6           1.60           6.64
# 2         CU  2021-10-03           75.5           1.46           6.88
#
#    player_name  batter  pitcher events    description  zone  \
# 0  Smith, Will  596019   519293    out  hit_into_play   1.0
# 1  Smith, Will  596019   519293    NaN           foul   4.0
# 2  Smith, Will  596019   519293    NaN           foul   5.0
#
#                                                  des stand p_throws home_team  \
# 0  Francisco Lindor grounds out, third baseman Eh...     R        L       ATL
# 1  Francisco Lindor grounds out, third baseman Eh...     R        L       ATL
# 2  Francisco Lindor grounds out, third baseman Eh...     R        L       ATL
#
#   away_team type  hit_location      bb_type  balls  strikes  game_year  pfx_x  \
# ...

# %%
w_smith = data.loc[data['player_name'] == 'Smith, Will'].copy()
w_smith['height'] = 6.42
w_smith['adj'] = w_smith['release_pos_z'] - w_smith['height'] * .7
w_smith['opp'] = abs(w_smith['adj'])
w_smith['hyp'] = np.sqrt(w_smith['opp'] ** 2 + w_smith['adj'] ** 2)
w_smith.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2021-10-03           92.3           1.40           6.80
# 1         SL  2021-10-03           80.6           1.60           6.64
# 2         CU  2021-10-03           75.5           1.46           6.88
# 3         CU  2021-10-03           75.0           1.53           6.83
# 4         FF  2021-10-03           91.2           1.49           6.66
#
#    player_name  batter  pitcher events    description  zone  \
# 0  Smith, Will  596019   519293    out  hit_into_play   1.0
# 1  Smith, Will  596019   519293    NaN           foul   4.0
# 2  Smith, Will  596019   519293    NaN           foul   5.0
# 3  Smith, Will  596019   519293    NaN           ball  12.0
# 4  Smith, Will  607043   519293    out  hit_into_play   4.0
#
#                                                  des stand p_throws home_team  \
# 0  Francisco Lindor grounds out, third baseman Eh...     R        L       ATL
# ...

# %%
w_smith['arm_angle'] = (np.arccos(((w_smith['adj']**2) + (w_smith['hyp'] ** 2) - (w_smith['opp'] ** 2))
                                  // (2 * (w_smith['adj'] * w_smith['hyp']))) * 100 / 2)
w_smith.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2021-10-03           92.3           1.40           6.80
# 1         SL  2021-10-03           80.6           1.60           6.64
# 2         CU  2021-10-03           75.5           1.46           6.88
# 3         CU  2021-10-03           75.0           1.53           6.83
# 4         FF  2021-10-03           91.2           1.49           6.66
#
#    player_name  batter  pitcher events    description  zone  \
# 0  Smith, Will  596019   519293    out  hit_into_play   1.0
# 1  Smith, Will  596019   519293    NaN           foul   4.0
# 2  Smith, Will  596019   519293    NaN           foul   5.0
# 3  Smith, Will  596019   519293    NaN           ball  12.0
# 4  Smith, Will  607043   519293    out  hit_into_play   4.0
#
#                                                  des stand p_throws home_team  \
# 0  Francisco Lindor grounds out, third baseman Eh...     R        L       ATL
# ...
